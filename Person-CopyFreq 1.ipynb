# %%
import random
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(74)


"""
source: https://medium.com/@ruthpolleitriechert/what-does-genre-in-art-mean-things-you-never-dared-to-ask-a-gallerist-d29b5f3e9dba
History Painting
Portraits
Genre Painting
Landscapes
Animal Painting
Still Life

vs. 

source: [https://www.lumas.com/art-genres/]
Renaissance
Rococo
Romanticism 
Expressionism
Impressionism
Surrealism
Abstract art
Bauhaus Art
Pop art
Realist Art
"""
# class Interests:
#     def __init__(self):
#         self.abstract = random.random()
#         self.realist = random.random()
#         self.romanticism = random.random()
#         self.surrealism = random.random()
  
def interestsGenerator():
        interestsVector = np.random.rand(4)
        # interestsVector[0]  #abstract
        # interestsVector[1]  #realist
        # interestsVector[2]  #romanticism
        # interestsVector[3]  #surrealism
        #normalize:
        interestsVector = interestsVector/np.linalg.norm(interestsVector)
        # print("norm is:", np.linalg.norm(interestsVector))
        return interestsVector

def printInfo(p):
        string = f"*****\nPersonInfo: \nID: {p.id}\nInterests: {p.interests}\nTimeSpent: {p.timeSpent}\n*****\n"
        print(string)

class Person:
    def get_interests(self):
        return self.interests
    
    def get_x(self):
        return self.posX
    def get_y(self):
        return self.posY
    def get_loc(self):
        return (self.posX, self.posY)
    def set_loc(self, newX, newY):
        self.posX = newX
        self.posY = newY
        
        
    def __init__(self):
        self.id = id(self)
        self.timeSpent = 0
        self.interests = interestsGenerator() #Interests()
        self.posX = -1 #-1 is outside the sim
        self.posY = -1 #-1 is outside the sim
        self.visited = [] #list of visited exhibits
        print(f"Person with ID {self.id} generated! Interests: {self.interests}")
        # printInfo(self)
    
p = Person()
p2 = Person()
p3 = Person()

class Exhibit:
    def __init__(self, loc, num):
        self.genres = interestsGenerator()
        (self.posX, self.posY) = loc
        self.num = num
    def get_genres(self):
        return self.genres
    
    def get_x(self):
        return self.posX
    def get_y(self):
        return self.posY
    def get_loc(self):
        return (self.posX, self.posY)
    def set_loc(self, newX, newY):
        self.posX = newX
        self.posY = newY

def dist(loc1, loc2): #loc1: (x, y) --> calcualtes the Euclidian distance btw 2 points
    return np.sqrt((loc1[0]-loc2[0])**2 + (loc1[1]-loc2[1])**2)
## Testing
# e1 = Exhibit()
# print(p.get_interests() @ e1.get_genres())
# print(p2.get_interests() @ e1.get_genres())
# p3.get_interests() @ e1.get_genres()
# Out:
# Person with ID 140489798293296 generated! Interests: [0.16488274 0.63974722 0.7017118  0.26671657]
# Person with ID 140489802575152 generated! Interests: [0.19286496 0.62802566 0.55290648 0.51252444]
# Person with ID 140489825164208 generated! Interests: [0.57984717 0.09214083 0.71000283 0.38882297]

# %%
## Creating the board
board_dim = (7, 10)
board = np.zeros(board_dim)
board[:, -1] = -1
board[:, 0] = -2
## Exhibit 1:
board[0,1:4] = -3
board[1,2] = -3
## Exhibit 2:
board[0,5:8] = -3
board[1,6] = -3
## Exhibit 3:
board[-1,1:4] = -3
board[-2,2] = -3
## Exhibit 4:
board[-1,5:8] = -3
board[-2,6] = -3


ex0c = (0,2)
ex1c = (0,6)
ex2c = (6, 2)
ex3c = (6, 6)
## Making the exhibits ex0 to ex3:
ex0 = Exhibit(ex0c, 0)
ex1 = Exhibit(ex1c, 1)
ex2 = Exhibit(ex2c, 2)
ex3 = Exhibit(ex3c, 3)
exhibits_lst = [ex0,ex1,ex2,ex3]

plt.imshow(board)
title_text = "Round (TODO)" + \
"\nFrequency of people being sent at every iteration In this round: (TODO) People per time step" + \
"\n" + \
"\nTimestep in this round: (TODO)" + \
"\nNumber of People present in the the hallway: (TODO)" + \
"\nNumber of people who've finished visiting the musuem hallway simulation (TODO)" + \
"\nFraction of space occupied: (TODO)" 
plt.title(title_text,fontsize='large',
    loc='left',
    fontweight='bold',
    style='italic',
    family='monospace')
plt.show()
# plt.subtitle("Frequency of sending people []. \n hi")
board_org = board.copy()

# %%
L = 4
b = 40
k = 0.09 
t = np.arange(0,30)
y = L/(1+b*np.exp(-k*t)) - L/(1+b)
plt.clf()
plt.plot(t, y)
plt.xlabel("timestep")
plt.ylabel("weight of the probablistic movement \ntowards the exit door of the halway")
plt.title("The curve representing the weight towards\n wanting to move towards the exit of the museum after\n a person has spent t time in the hallway")
plt.show()
# plt.savefig("Exiting weight progression.jpeg")

def calc_exit_pref(t): #t is time spent in the hallway
    return L/(1+b*np.exp(-k*t)) - (L/(1+b))*0.99 # to have sum of weight >=0

# %%
# @@ Cell 4 (RECOVERED):
#testing
# %matplotlib inline
# %matplotlib osx
plt_1 = plt.figure(figsize=(10, 10))
board2 = np.zeros(board_org.shape)
board2[5,5] = 10
plt.clf()
plt.imshow(board2)
plt.imshow(board_org, alpha=0.1)#, cmap="Greys")
# title_text = title_generator(1,2,3,4,5,6)
# plt.suptitle(title_text,fontsize='large',
#         wrap=True,
# #         loc='left',
#         fontweight='bold',
#         style='italic',
#         family='monospace')
plt.figtext(0.5, 0.01, "one text and next text", ha="center", fontsize=18, bbox={"facecolor":"orange", "alpha":0.5, "pad":5})
plt.show()
# plt.savefig("./images/im-1.jpeg")

# %%
# @@ Cell 5 (RECOVERED):
people_placements = np.zeros(board_dim) # 1 or 0 based on whether occupied or not --> #sunsetting this
people_present_lst = []
people_done_lst = [] #list of people who've successfully finished the simulation
roundNum = 1
freq = 3 #frequency of sending f people per iteration (TOCHANGE)
timesteps = 100
round_num = 0
occupied_value = 10

def title_generator(roundNum, freq, timestep, numPresent, numFinished, fracSpaceOcc):
    title_text = f"Round {roundNum}" + \
f"\nFrequency of people being sent at every iteration In this round: {freq} People per time step" + \
"\n" + \
f"\nTimestep in this round: {timestep}" + \
f"\nNumber of People present in the the hallway: {numPresent}" + \
f"\nNumber of people who've finished visiting the musuem hallway simulation {numFinished}" + \
f"\nFraction of space occupied: {fracSpaceOcc}" 
    return title_text
# print(title_generator(1,2,3,4,5,6))
def numPresentCounter(board):
    return np.count_nonzero(board == occupied_value)

# %%
for freq in range(2,7+1):
    # @@ Cell 6 (RECOVERED):
    plt.rcParams["figure.figsize"] = (10, 10)
    board = np.zeros(board_org.shape) #reset the board
    # %matplotlib osx
    ## %matplotlib osx
    ## %matplotlib inline
    get_ipython().run_line_magic('matplotlib', 'osx')
    from matplotlib.animation import FFMpegWriter
    metadata = dict(title='CrowdSim', artist='Matplotlib',comment='Maryam Azmandian 2022')
    writer = FFMpegWriter(fps=15, metadata=metadata)
    fig = plt.figure()
    with writer.saving(fig, f"FREQ{freq} crowdsim.mp4", dpi=200):

        ## grab the first frame
        plt.clf()
        plt.rcParams["figure.figsize"] = (10, 10)
    #     plt.imshow(board_org)
    # #     plt.imshow(board, alpha=0.5)#, cmap="Greys")
        title_text = title_generator(roundNum, freq, 0, 0, 0, 0)
        title_text0 = title_text.split('\n\n')[0]
        plt.suptitle(title_text0,fontsize='large',
            wrap=True,
    #         loc='left',
            fontweight='bold',
            style='italic',
            family='monospace')
        #"\n\n\n\n\n\n\n\n\n\n"
    #     plt.figtext(0.5, 0.01, title_text, ha="center", fontsize=18, bbox={"facecolor":"orange", "alpha":0.5, "pad":10})
        title_text = title_text.split('\n\n')[1]
        plt.figtext(0.5, 0.01, title_text, ha="center", wrap=True, fontsize=10, bbox={"facecolor":"orange", "alpha":0.5, "pad":40})

        plt.imshow(board)
        plt.imshow(board_org, alpha=0.1)#, cmap="Greys")
        plt.show()
    #     plt.savefig("./images/im0.jpeg")
        plt.draw()
        plt.pause(0.05)
        writer.grab_frame()
        ## grab the first frame
        for t in range(timesteps):
            if (t%10==0): print(t,end='')
            print('.',end='')


            #logic here

            # step 1: create people to be entering
            people_created = []
            for i in range(freq):
                p = Person()
                p.set_loc(i,9)
                #people_placements[i,9] = 1 #sunsetting this line
                board[i, 9] = occupied_value
                people_created.append(p)
                people_present_lst.append(p)


            # step 2: have them decide to move, handle exit logic
            for p in people_present_lst:
                pref_weights = []
                for exh in exhibits_lst:
                    distance = dist(p.get_loc(), exh.get_loc())
                    if distance <=1: # check if being visited
                        p.visited.append(exh)
                    if exh not in p.visited:
                        pref = np.dot(p.get_interests(), ex0.get_genres())
                        pref += 1/distance # no danger of div by zero error here
                    else:
                        pref = 0
                    pref_weights.append(pref)
                exit_pref = calc_exit_pref(p.timeSpent) #to make sure non_negative
                pref_weights.append(exit_pref)
                choice = random.choices(exhibits_lst + [0], weights=pref_weights, k=1)[0] #0 denotes choice of exit path
                (curX, curY) = p.get_loc()
                if choice == 0: #decide to move towards the exit
                    (toX, toY) = (curX, (curY-1)%board.shape[1]) # then want to move to the left after checking occupancy

                    if board[toX, toY] != occupied_value:
                        board[curX, curY] = 0
                        board[toX, toY] = occupied_value
                        p.set_loc(toX,toY)
                else: #choice is an exhibit obj, we need to move towards a loc
                    (exhX, exhY) = choice.get_loc()
                    x_adder = ((exhX < curX) * -1) + ((exhX > curX) * 1 )
                    y_adder = ((exhY < curY) * -1) + ((exhY > curY) * 1 )
                    (toX, toY) = (curX, curY)
                    if board[x_adder+curX,curY] != occupied_value:
                        (toX, toY) = (x_adder+curX,curY)
                    elif board[curX, y_adder + curY] != occupied_value:
                        (toX, toY) = (curX, y_adder + curY)
                    #otherwise stay in place.
                    if (toX, toY) != (curX, curY):
                        board[curX, curY] = 0
                        board[toX, toY] = occupied_value
                        p.set_loc(toX,toY)



                if p.get_y == 0: #if we're at the exit
                    (curX, curY) = p.get_loc()
                    board[curX, curY] = 0
                    people_done_lst.append(p)
                    p.set_loc((-1,-1)) #update p's loc to being outside the hallway

                    #can add working towards the exit as a preference too!!!
                    #logistics growth for time: y = L/(1+b*exp(-kt))


            #remove people who've exited from the people present in the hallway
            set1 = set(people_present_lst)
            set2 = set(people_done_lst)
            people_present_lst = list(set1 - set2)



    #         plt.figure(figsize = (10,10))
    #         plt.imshow(img_1)
    #         plt.imshow(img_2, alpha=0.5)

            plt.clf()
            plt.rcParams["figure.figsize"] = (10, 10)
    # #         plt.imshow(board_org)
    #         plt.imshow(board, alpha=0.5, cmap="Greys")
            plt.imshow(board)
            plt.imshow(board_org, alpha=0.1)#, cmap="Greys")
            numPresent = len(people_present_lst)
            fracSpaceOcc = numPresentCounter(board)/board.size#len(people_present_lst)/board.size
            if fracSpaceOcc>0.99:
                print("CROWDCRUSH OCCURED!")
                break;
            title_text = title_generator(roundNum, freq, t, numPresent, len(people_done_lst), fracSpaceOcc)
            title_text0 = title_text.split('\n\n')[0]
            plt.suptitle(title_text0,fontsize='large',
            wrap=True,
    #         loc='left',
            fontweight='bold',
            style='italic',
            family='monospace')
            title_text = title_text.split('\n\n')[1]
            plt.figtext(0.5, 0.01, title_text, ha="center", wrap=True, fontsize=10, bbox={"facecolor":"orange", "alpha":0.5, "pad":40})
            plt.show()
    #         plt.savefig(f"./images/im{t}.jpeg")
            plt.draw()
            plt.pause(0.05)
            writer.grab_frame()
# Out:
# 0.Person with ID 140489829168848 generated! Interests: [0.22727555 0.51602772 0.80700811 0.17549678]
# Person with ID 140489798293296 generated! Interests: [0.02998725 0.60709723 0.45987128 0.64734236]
# .Person with ID 140489826521040 generated! Interests: [0.20473335 0.09174404 0.65720443 0.71954821]
# Person with ID 140489826520896 generated! Interests: [0.58088956 0.66752232 0.44476748 0.13843107]
# .Person with ID 140489826334224 generated! Interests: [0.18562193 0.20049619 0.71338175 0.64531562]
# Person with ID 140489826663584 generated! Interests: [0.38683259 0.72276452 0.19708226 0.53770865]
# .Person with ID 140489755224672 generated! Interests: [0.27175986 0.35329989 0.56663933 0.69299757]
# Person with ID 140489829169232 generated! Interests: [0.56315756 0.62039941 0.54561939 0.01605076]
# .Person with ID 140489827270416 generated! Interests: [0.80008579 0.33708642 0.49365786 0.05037247]
# Person with ID 140489827269264 generated! Interests: [0.9172212  0.12657071 0.2397278  0.29191729]
# .Person with ID 140489827511264 generated! Interests: [0.41979653 0.88197587 0.00252261 0.21420335]
# Person with ID 140489827511936 generated! Interests: [0.63810773 0.6880448  0.12706141 0.32135381]
# .Person with ID 140489755249344 generated! Interests: [0.65617587 0.32739745 0.67789082 0.05204018]
# Person with ID 140489755249632 generated! Interests: [0.05526892 0.64715667 0.66098482 0.37580934]
# .Person with ID 140489430715600 generated! Interests: [0.59572092 0.12447784 0.29589331 0.73625336]
# Person with ID 140489430713872 generated! Interests: [0.63869041 0.41702663 0.10232422 0.6385085 ]
# .Person with ID 140489827423760 generated! Interests: [0.31814959 0.70500692 0.0944394  0.62675935]
# Person with ID 140489827423280 generated! Interests: [0.36997769 0.59720309 0.03470915 0.71081661]
# .Person with ID 140489430904640 generated! Interests: [0.46484453 0.33651301 0.57044808 0.58759471]
# Person with ID 140489450699264 generated! Interests: [0.02494527 0.65799861 0.64912927 0.38085004]
# 10.Person with ID 140489828208800 generated! Interests: [0.40976807 0.69366213 0.59164028 0.02974478]
# Person with ID 140489828360784 generated! Interests: [0.5025247  0.59108762 0.30847841 0.55038662]
# .Person with ID 140489826661424 generated! Interests: [0.19513261 0.29782259 0.59513764 0.72044164]
# Person with ID 140489826660800 generated! Interests: [0.124798   0.25971395 0.60221108 0.74452397]
# .Person with ID 140489826333936 generated! Interests: [0.17271333 0.44876211 0.617583   0.6223937 ]
# Person with ID 140489826333360 generated! Interests: [0.59671    0.2388915  0.43649182 0.62955772]
# .Person with ID 140489755225968 generated! Interests: [0.73031141 0.31595593 0.19642398 0.57291773]
# Person with ID 140489755222752 generated! Interests: [0.62024148 0.24901071 0.73384754 0.12149882]
# .Person with ID 140489829085872 generated! Interests: [0.85472242 0.50372081 0.0541258  0.11307225]
# Person with ID 140489829085488 generated! Interests: [0.43089152 0.7750948  0.02041541 0.46167494]
# .Person with ID 140489826697472 generated! Interests: [0.66046362 0.04254772 0.71800566 0.21551188]
# Person with ID 140489826298416 generated! Interests: [0.48402972 0.63103881 0.57188734 0.20112217]
# .Person with ID 140489798635472 generated! Interests: [0.82895653 0.43577824 0.34281634 0.0735211 ]
# Person with ID 140489798293488 generated! Interests: [0.36905406 0.64357467 0.06197987 0.66765952]
# .Person with ID 140489825532368 generated! Interests: [0.25600733 0.5758325  0.34314712 0.69651076]
# Person with ID 140489825805360 generated! Interests: [0.43470607 0.39147545 0.59286532 0.55343322]
# .Person with ID 140489825099152 generated! Interests: [0.5988026  0.73340671 0.31285517 0.0753106 ]
# Person with ID 140489828952384 generated! Interests: [0.08227274 0.2645673  0.23506588 0.9316541 ]
# .Person with ID 140489755311024 generated! Interests: [0.64404077 0.42726596 0.41591967 0.47923492]
# Person with ID 140489798636208 generated! Interests: [0.45863601 0.86218645 0.01850223 0.21434832]
# 20.Person with ID 140489827508336 generated! Interests: [0.14827876 0.41826181 0.67217855 0.5926605 ]
# Person with ID 140489829044960 generated! Interests: [0.88188317 0.348577   0.25501617 0.18905792]
# .Person with ID 140489828952768 generated! Interests: [0.10228682 0.45320399 0.47743928 0.74578502]
# Person with ID 140489825572032 generated! Interests: [0.3232236  0.50775351 0.5583396  0.57093762]
# .Person with ID 140489826720160 generated! Interests: [0.44700293 0.46597713 0.76267291 0.03719858]
# Person with ID 140489826721696 generated! Interests: [0.50312804 0.55632807 0.64824925 0.13089756]
# .Person with ID 140489828216448 generated! Interests: [0.64510386 0.466502   0.29616754 0.52773259]
# Person with ID 140489828216736 generated! Interests: [0.65161805 0.69192359 0.01838255 0.31031877]
# .Person with ID 140489579128624 generated! Interests: [0.14806265 0.72860209 0.11920044 0.6580332 ]
# Person with ID 140489450918624 generated! Interests: [0.43017902 0.1814216  0.77235374 0.43069933]
# .Person with ID 140489826548992 generated! Interests: [0.62647162 0.16846855 0.15698338 0.74465286]
# Person with ID 140489579276656 generated! Interests: [0.47750697 0.04987844 0.37570118 0.79268396]
# .Person with ID 140489450765712 generated! Interests: [0.28819001 0.40648006 0.57570725 0.64829133]
# Person with ID 140489579387488 generated! Interests: [0.13107185 0.04078074 0.90941996 0.39257157]
# .Person with ID 140489450766000 generated! Interests: [0.57395852 0.31718448 0.56915398 0.49601348]
# Person with ID 140489450765808 generated! Interests: [0.45937784 0.33563347 0.54334986 0.61732738]
# .Person with ID 140489579129056 generated! Interests: [0.95427516 0.21682766 0.19209498 0.07378478]
# Person with ID 140489640082928 generated! Interests: [0.51830532 0.42975646 0.45204341 0.58508609]
# .Person with ID 140489579415536 generated! Interests: [0.0177913  0.05851409 0.93403083 0.35191757]
# Person with ID 140489450763888 generated! Interests: [0.30895028 0.56084749 0.57928521 0.50440902]
# 30.Person with ID 140489579152720 generated! Interests: [0.57548267 0.56473226 0.12410964 0.57835453]
# Person with ID 140489826476576 generated! Interests: [0.17060624 0.57174013 0.77762103 0.19827321]
# .Person with ID 140489827396624 generated! Interests: [0.70063427 0.70175531 0.04758144 0.1199463 ]
# Person with ID 140489825533712 generated! Interests: [0.54999294 0.6714471  0.49608604 0.02377362]
# .Person with ID 140489826476672 generated! Interests: [0.57528842 0.46339148 0.45164574 0.50032758]
# Person with ID 140489826480080 generated! Interests: [0.73599641 0.39538582 0.49589623 0.23678316]
# .Person with ID 140489827394320 generated! Interests: [0.7056484  0.66417731 0.01599201 0.24631909]
# Person with ID 140489825869888 generated! Interests: [0.77463076 0.03920838 0.63091132 0.01899434]
# .Person with ID 140489825438592 generated! Interests: [0.73022809 0.63007881 0.21708228 0.15047564]
# Person with ID 140489825436048 generated! Interests: [0.83095214 0.07804638 0.057694   0.54781265]
# .Person with ID 140489831677904 generated! Interests: [0.56882603 0.37580634 0.56933197 0.45942099]
# Person with ID 140489825686624 generated! Interests: [0.53513626 0.62321498 0.51505793 0.244842  ]
# .Person with ID 140489826520176 generated! Interests: [0.47590421 0.57656698 0.49259215 0.44546455]
# Person with ID 140489826518112 generated! Interests: [0.16749272 0.84666622 0.19862189 0.46438329]
# .Person with ID 140489826701024 generated! Interests: [0.11918835 0.91878269 0.21721831 0.3073251 ]
# Person with ID 140489826385776 generated! Interests: [0.11648448 0.53612934 0.20576977 0.81034283]
# .Person with ID 140489579387968 generated! Interests: [0.23921774 0.38106376 0.83414951 0.31899824]
# Person with ID 140489826517248 generated! Interests: [0.40626451 0.51534917 0.48067645 0.58164811]
# .Person with ID 140489754893280 generated! Interests: [0.58788786 0.65400069 0.27785717 0.38660879]
# Person with ID 140489826680256 generated! Interests: [0.53533912 0.56052968 0.50519345 0.37947078]
# 40.Person with ID 140489829167744 generated! Interests: [0.46353274 0.43816462 0.15201067 0.75501121]
# Person with ID 140489829169088 generated! Interests: [0.27369287 0.62310688 0.70457646 0.20100259]
# .Person with ID 140489826660944 generated! Interests: [0.80373113 0.17544552 0.56674123 0.045161  ]
# Person with ID 140489826664208 generated! Interests: [0.21666094 0.02622754 0.58429161 0.78164792]
# .Person with ID 140489430903200 generated! Interests: [0.48371595 0.22042846 0.30830085 0.78891113]
# Person with ID 140489827470160 generated! Interests: [0.64733271 0.43721363 0.07262889 0.62010455]
# .Person with ID 140489827510928 generated! Interests: [0.64527991 0.57978214 0.31776067 0.38274621]
# Person with ID 140489827509824 generated! Interests: [0.30202059 0.58348805 0.22196031 0.72045741]
# .Person with ID 140489579108144 generated! Interests: [0.87830412 0.1272123  0.03199572 0.45975556]
# Person with ID 140489579172960 generated! Interests: [0.5384885  0.76837532 0.24804195 0.24104913]
# .Person with ID 140489430903584 generated! Interests: [0.10180756 0.81651094 0.45910477 0.33491478]
# Person with ID 140489827269600 generated! Interests: [0.88076733 0.10623933 0.43098023 0.16497927]
# .Person with ID 140489579174448 generated! Interests: [0.24145221 0.12977614 0.58107884 0.76629391]
# Person with ID 140489827268064 generated! Interests: [0.03733894 0.45966489 0.63653054 0.61817705]
# .Person with ID 140489827062016 generated! Interests: [0.58491638 0.5264661  0.1287039  0.60344145]
# Person with ID 140489430739936 generated! Interests: [0.67275265 0.20730384 0.27815199 0.65349863]
# .Person with ID 140489827181808 generated! Interests: [0.35565647 0.46057245 0.4511749  0.67662596]
# Person with ID 140489827511024 generated! Interests: [0.48924015 0.49757464 0.52682706 0.48530073]
# .Person with ID 140489827325744 generated! Interests: [0.39769924 0.09387075 0.79983761 0.43964009]
# Person with ID 140489827327232 generated! Interests: [0.3368156  0.06347339 0.64099997 0.68676446]
# 50.Person with ID 140489827468432 generated! Interests: [8.82395885e-05 5.66843316e-01 5.32342544e-01 6.28728926e-01]
# Person with ID 140489827470496 generated! Interests: [0.68205469 0.45537726 0.22985385 0.52402306]
# .Person with ID 140489827219920 generated! Interests: [0.43652813 0.5696932  0.6919945  0.07769464]
# Person with ID 140489579174400 generated! Interests: [0.10707787 0.20433133 0.74195788 0.62950897]
# .Person with ID 140489831735792 generated! Interests: [0.74960873 0.49218624 0.08058706 0.43513812]
# Person with ID 140489754892992 generated! Interests: [0.68946124 0.44795368 0.0409951  0.5677148 ]
# .Person with ID 140489430749088 generated! Interests: [0.28854438 0.02537677 0.52223182 0.80210478]
# Person with ID 140489430746784 generated! Interests: [0.33308663 0.5816669  0.61353404 0.41748402]
# .Person with ID 140489826356288 generated! Interests: [0.59379233 0.7250428  0.03878477 0.34672662]
# Person with ID 140489825900528 generated! Interests: [0.22786873 0.67780057 0.42980058 0.55130182]
# .Person with ID 140489755311744 generated! Interests: [0.29989265 0.24989239 0.09623987 0.91561787]
# Person with ID 140489755311312 generated! Interests: [0.65208445 0.09342784 0.58000049 0.47922493]
# .Person with ID 140489430849088 generated! Interests: [0.57513215 0.44882021 0.31125821 0.60901705]
# Person with ID 140489825806608 generated! Interests: [0.15096923 0.51812455 0.4683612  0.69956632]
# .Person with ID 140489798550528 generated! Interests: [0.11031611 0.69924743 0.60550295 0.36366135]
# Person with ID 140489829125184 generated! Interests: [0.55006889 0.0304261  0.08289857 0.83043741]
# .Person with ID 140489829047504 generated! Interests: [0.00296013 0.40264508 0.62837747 0.66558991]
# Person with ID 140489755308816 generated! Interests: [0.38390553 0.67558864 0.53531487 0.33111103]
# .Person with ID 140489825688256 generated! Interests: [0.53963618 0.62647447 0.4584205  0.32584227]
# Person with ID 140489825276448 generated! Interests: [0.60465249 0.47852784 0.62114672 0.13994012]
# 60.Person with ID 140489825844720 generated! Interests: [0.63231355 0.2886339  0.54707042 0.466459  ]
# Person with ID 140489827396192 generated! Interests: [0.15092292 0.92488338 0.33631976 0.09328462]
# .Person with ID 140489828216352 generated! Interests: [0.06391809 0.83612766 0.10781435 0.53402349]
# Person with ID 140489828212992 generated! Interests: [0.67822956 0.48878305 0.43321674 0.33677745]
# .Person with ID 140489450829328 generated! Interests: [0.42278789 0.42364848 0.58583786 0.54641227]
# Person with ID 140489450829712 generated! Interests: [0.60975741 0.50337519 0.60423473 0.09853787]
# .Person with ID 140489798631488 generated! Interests: [0.08749729 0.31011172 0.45964705 0.82758657]
# Person with ID 140489827395760 generated! Interests: [0.52919783 0.24276283 0.66366697 0.46964031]
# .Person with ID 140489826547600 generated! Interests: [0.63519015 0.13939828 0.72401048 0.23002265]
# Person with ID 140489828293360 generated! Interests: [0.24819798 0.63473977 0.52043379 0.51444325]
# .Person with ID 140489450829520 generated! Interests: [0.57159986 0.07264489 0.30984924 0.75630005]
# Person with ID 140489450763216 generated! Interests: [0.46358418 0.00207625 0.63663487 0.6162641 ]
# .Person with ID 140489579560768 generated! Interests: [0.20704795 0.04967519 0.94181709 0.26008479]
# Person with ID 140489579560048 generated! Interests: [0.27682467 0.68379373 0.0382756  0.67403948]
# .Person with ID 140489579388880 generated! Interests: [0.70275618 0.46717778 0.52292971 0.12009661]
# Person with ID 140489579386960 generated! Interests: [0.64411948 0.5935695  0.4763316  0.07676945]
# .Person with ID 140489640112528 generated! Interests: [0.48732726 0.7050583  0.21661455 0.46742173]
# Person with ID 140489798635680 generated! Interests: [0.62254688 0.53263563 0.38420663 0.42558189]
# .Person with ID 140489825532128 generated! Interests: [0.3022812  0.69593503 0.3056882  0.57520017]
# Person with ID 140489825531984 generated! Interests: [0.87622527 0.29370022 0.1356902  0.35715209]
# 70.Person with ID 140489640082400 generated! Interests: [0.41504691 0.48200212 0.1829194  0.74963358]
# Person with ID 140489640079616 generated! Interests: [0.35306041 0.87401033 0.29760666 0.15127644]
# .Person with ID 140489826100224 generated! Interests: [0.90660761 0.20169667 0.36330345 0.07342814]
# Person with ID 140489829046976 generated! Interests: [0.15788241 0.72010581 0.25929725 0.62392764]
# .Person with ID 140489755309200 generated! Interests: [0.46006319 0.4591843  0.4997174  0.57251564]
# Person with ID 140489755310064 generated! Interests: [0.04278958 0.52106906 0.71146452 0.46954693]
# .Person with ID 140489755362880 generated! Interests: [0.41743022 0.86850759 0.23380911 0.12953716]
# Person with ID 140489755363600 generated! Interests: [0.83577795 0.45993279 0.02551307 0.29880784]
# .Person with ID 140489829013728 generated! Interests: [0.65925227 0.33560197 0.35848261 0.56942776]
# Person with ID 140489826296976 generated! Interests: [0.18764716 0.68987945 0.68681587 0.13091542]
# .Person with ID 140489829169040 generated! Interests: [0.70128848 0.65483872 0.126095   0.2519539 ]
# Person with ID 140489829168032 generated! Interests: [0.29181875 0.49888822 0.52839736 0.62189114]
# .Person with ID 140489579174064 generated! Interests: [0.38107929 0.34322365 0.63183096 0.58117617]
# Person with ID 140489579172624 generated! Interests: [0.535813   0.51768011 0.65492669 0.12642295]
# .Person with ID 140489826677472 generated! Interests: [0.55887145 0.76037584 0.3127503  0.10806724]
# Person with ID 140489827426064 generated! Interests: [0.09049804 0.20792904 0.71591028 0.66033938]
# .Person with ID 140489826270800 generated! Interests: [0.64945966 0.34193141 0.46257737 0.49729994]
# Person with ID 140489430748704 generated! Interests: [0.82884532 0.34298778 0.21388394 0.38681841]
# .Person with ID 140489430737584 generated! Interests: [0.46917156 0.56559391 0.45602186 0.50202155]
# Person with ID 140489430738016 generated! Interests: [0.48741592 0.7495848  0.37972345 0.23739936]
# 80.Person with ID 140489827183680 generated! Interests: [0.79251036 0.14282829 0.4647043  0.36820826]
# Person with ID 140489827302416 generated! Interests: [0.27382407 0.53900067 0.58553301 0.54004607]
# .Person with ID 140489827325168 generated! Interests: [0.06426747 0.29613108 0.72809431 0.61486158]
# Person with ID 140489825574864 generated! Interests: [0.01608465 0.27033681 0.28355121 0.91992282]
# .Person with ID 140489827326032 generated! Interests: [0.11124662 0.58580563 0.66655273 0.44739627]
# Person with ID 140489827326752 generated! Interests: [0.6652088  0.26115335 0.21417787 0.6659009 ]
# .Person with ID 140489430839200 generated! Interests: [0.68166612 0.18439413 0.04731356 0.70646411]
# Person with ID 140489579130832 generated! Interests: [0.61150747 0.08477452 0.70292901 0.35321764]
# .Person with ID 140489640033344 generated! Interests: [0.22899511 0.66473282 0.56323815 0.43411323]
# Person with ID 140489640032960 generated! Interests: [0.06521721 0.15977314 0.81390902 0.55477146]
# .Person with ID 140489428513312 generated! Interests: [0.28049918 0.36694066 0.42924615 0.77615882]
# Person with ID 140489428515808 generated! Interests: [0.67048367 0.34765101 0.03444276 0.65452588]
# .Person with ID 140489579175744 generated! Interests: [0.0215867  0.81622982 0.32496088 0.4771827 ]
# Person with ID 140489579175888 generated! Interests: [0.49125743 0.34578854 0.46325948 0.65152673]
# .Person with ID 140489827184112 generated! Interests: [0.72035201 0.45437738 0.4655882  0.24054482]
# Person with ID 140489827182672 generated! Interests: [0.355644   0.32021082 0.46072684 0.74747117]
# .Person with ID 140489428514560 generated! Interests: [0.98974872 0.09123476 0.07135186 0.08356196]
# Person with ID 140489826663008 generated! Interests: [0.51525591 0.00644502 0.81899746 0.25241428]
# .Person with ID 140489640143840 generated! Interests: [0.42417549 0.54457454 0.72320495 0.02209805]
# Person with ID 140489826583648 generated! Interests: [0.04555022 0.49339422 0.85937484 0.12634166]
# 90.Person with ID 140489826353744 generated! Interests: [0.44050001 0.44113528 0.24905378 0.74116909]
# Person with ID 140489826353840 generated! Interests: [0.2711462  0.51875405 0.04653705 0.80944937]
# .Person with ID 140489755309872 generated! Interests: [0.22964649 0.87409324 0.34335088 0.25560453]
# Person with ID 140489827011840 generated! Interests: [0.97018564 0.06574453 0.0781718  0.21978775]
# .Person with ID 140489826100992 generated! Interests: [0.43351095 0.25480345 0.55459601 0.66299828]
# Person with ID 140489826101760 generated! Interests: [0.62588491 0.47270124 0.52121481 0.33638777]
# .Person with ID 140489797847072 generated! Interests: [0.92684782 0.00256638 0.19926317 0.31818347]
# Person with ID 140489826299712 generated! Interests: [0.01189349 0.02620106 0.66256134 0.74845475]
# .Person with ID 140489826333408 generated! Interests: [0.11315927 0.22169376 0.75191175 0.61047161]
# Person with ID 140489797847264 generated! Interests: [0.59760872 0.45941413 0.51910038 0.40291099]
# .Person with ID 140489825277024 generated! Interests: [0.08305514 0.64253665 0.68865107 0.325589  ]
# Person with ID 140489825276304 generated! Interests: [0.2578389  0.94076322 0.17817446 0.12937364]
# .Person with ID 140489826477440 generated! Interests: [0.55449176 0.360689   0.47361016 0.5814944 ]
# Person with ID 140489825435952 generated! Interests: [0.29443023 0.56266158 0.76942798 0.06858119]
# .Person with ID 140489828216640 generated! Interests: [0.4344803  0.13270279 0.60625351 0.65274308]
# Person with ID 140489826549712 generated! Interests: [0.64277199 0.32262897 0.6726631  0.17400882]
# .Person with ID 140489579400640 generated! Interests: [0.51513902 0.50992472 0.09465085 0.68238536]
# Person with ID 140489579397328 generated! Interests: [0.35239573 0.71035802 0.60711914 0.05113791]
# .Person with ID 140489450763168 generated! Interests: [0.03582054 0.52900503 0.70233191 0.47497415]
# Person with ID 140489450762640 generated! Interests: [0.21974873 0.47967998 0.2999014  0.79478095]
# 0.Person with ID 140489797611232 generated! Interests: [0.60935313 0.53535472 0.43884151 0.38665516]
# Person with ID 140489826520800 generated! Interests: [0.09252053 0.10647136 0.9513421  0.27395621]
# Person with ID 140489825841936 generated! Interests: [0.69642035 0.00506347 0.48999663 0.52428653]
# .Person with ID 140489428601632 generated! Interests: [0.71111283 0.33381989 0.53687416 0.3076507 ]
# Person with ID 140489428601776 generated! Interests: [0.02883054 0.40715446 0.28827209 0.8661947 ]
# Person with ID 140489428601872 generated! Interests: [0.04761867 0.65692383 0.3030482  0.68872733]
# .Person with ID 140489579385808 generated! Interests: [0.09153543 0.77789745 0.40406565 0.47246985]
# Person with ID 140489826549280 generated! Interests: [0.51319215 0.11676676 0.8329873  0.17067951]
# Person with ID 140489826549520 generated! Interests: [0.50146246 0.29975499 0.5553358  0.59184837]
# .Person with ID 140489798401664 generated! Interests: [0.44076639 0.43234693 0.3848231  0.68608476]
# Person with ID 140489831624224 generated! Interests: [0.28120502 0.15650547 0.55281747 0.76864987]
# Person with ID 140489831621536 generated! Interests: [0.44155595 0.46550477 0.0279972  0.76651798]
# .Person with ID 140489826548752 generated! Interests: [0.5086846  0.28005566 0.61199152 0.53691264]
# Person with ID 140489450774976 generated! Interests: [0.25748036 0.48993374 0.29149941 0.78019029]
# Person with ID 140489825924576 generated! Interests: [1.44695244e-01 4.32933829e-01 6.06037784e-04 8.89736601e-01]
# .Person with ID 140489826336384 generated! Interests: [0.76144697 0.50537008 0.0069936  0.40589492]
# Person with ID 140489826332832 generated! Interests: [0.70183523 0.19915577 0.30997839 0.60965374]
# Person with ID 140489826334080 generated! Interests: [0.68177914 0.07686695 0.0549474  0.72543053]
# .Person with ID 140489826679008 generated! Interests: [0.4234328  0.31065878 0.57242601 0.62970171]
# Person with ID 140489755249536 generated! Interests: [0.43027236 0.23542031 0.70722413 0.5091925 ]
# Person with ID 140489755247328 generated! Interests: [0.6140562  0.72092073 0.32125904 0.00095347]
# .Person with ID 140489831736080 generated! Interests: [0.10538552 0.45142458 0.54668588 0.69731219]
# Person with ID 140489826660896 generated! Interests: [0.56104331 0.45002653 0.41190627 0.55949955]
# Person with ID 140489826662000 generated! Interests: [0.33742646 0.70467155 0.16548246 0.601828  ]
# .Person with ID 140489430797952 generated! Interests: [0.69417735 0.57577684 0.40988605 0.13635345]
# Person with ID 140489430794400 generated! Interests: [0.81417876 0.42731334 0.06701218 0.3873314 ]
# Person with ID 140489825872432 generated! Interests: [0.15200829 0.23187213 0.25530659 0.92625447]
# .Person with ID 140489826385728 generated! Interests: [0.12845217 0.53896137 0.79378456 0.25085204]
# Person with ID 140489826664160 generated! Interests: [2.07950117e-01 7.74045586e-01 3.64995472e-04 5.98005056e-01]
# Person with ID 140489827181520 generated! Interests: [0.10700072 0.80302446 0.57310524 0.12350282]
# 10.Person with ID 140489827469632 generated! Interests: [0.73552968 0.11957329 0.6510982  0.14411615]
# Person with ID 140489831738384 generated! Interests: [0.04748804 0.33852729 0.67736183 0.65140242]
# Person with ID 140489826661040 generated! Interests: [0.69338519 0.55801198 0.30362642 0.3400744 ]
# .Person with ID 140489827326272 generated! Interests: [0.20532738 0.72767575 0.59553745 0.27141078]
# Person with ID 140489829071744 generated! Interests: [0.17312866 0.77956109 0.3543477  0.48656826]
# Person with ID 140489829069728 generated! Interests: [0.75409213 0.12438417 0.05637417 0.64241388]
# .Person with ID 140489428451584 generated! Interests: [0.65786407 0.04127342 0.72203907 0.21016886]
# Person with ID 140489428454320 generated! Interests: [0.45417225 0.34072665 0.62297179 0.53808834]
# Person with ID 140489428514512 generated! Interests: [0.30514578 0.85602814 0.23375636 0.34562962]
# .Person with ID 140489798636304 generated! Interests: [0.08842255 0.55561867 0.38790656 0.73006701]
# Person with ID 140489798638848 generated! Interests: [0.57507489 0.03434455 0.01752342 0.81719169]
# Person with ID 140489798638368 generated! Interests: [0.53446155 0.4860896  0.67281419 0.1593387 ]
# .Person with ID 140489826698336 generated! Interests: [0.47868598 0.43731633 0.38427811 0.65722484]
# Person with ID 140489828211632 generated! Interests: [0.37248748 0.46266395 0.45735225 0.66183387]
# Person with ID 140489828211440 generated! Interests: [0.58253759 0.22091811 0.62870676 0.46537399]
# .Person with ID 140489825277936 generated! Interests: [0.01105854 0.61586239 0.36672394 0.69721214]
# Person with ID 140489579277472 generated! Interests: [0.24253465 0.64772795 0.1859274  0.69789429]
# Person with ID 140489579275984 generated! Interests: [0.28518218 0.19334166 0.79089952 0.50573518]
# .Person with ID 140489827220544 generated! Interests: [0.53122495 0.73459176 0.39296702 0.15411656]
# Person with ID 140489430747024 generated! Interests: [0.04730205 0.21812827 0.44059298 0.86951734]
# Person with ID 140489825804400 generated! Interests: [0.4957243  0.1491232  0.74912246 0.41332218]
# .Person with ID 140489827300064 generated! Interests: [0.65749957 0.02854341 0.58037063 0.47963478]
# Person with ID 140489827299920 generated! Interests: [0.57264667 0.7795506  0.15100141 0.20390004]
# Person with ID 140489579066128 generated! Interests: [0.71614597 0.34045672 0.0415129  0.60786582]
# .Person with ID 140489450699552 generated! Interests: [0.4361378  0.24304366 0.7176677  0.48545511]
# Person with ID 140489640079664 generated! Interests: [0.31941975 0.49513925 0.08203008 0.80379053]
# Person with ID 140489450699120 generated! Interests: [0.85197524 0.13810033 0.06195886 0.50122609]
# .Person with ID 140488669874928 generated! Interests: [0.5525608  0.66063797 0.49312526 0.12272537]
# Person with ID 140489579235840 generated! Interests: [0.63302769 0.4295119  0.59851433 0.23785725]
# Person with ID 140489579236128 generated! Interests: [0.6426668  0.29520612 0.35382011 0.61208174]
# 20.Person with ID 140488670019008 generated! Interests: [0.56303289 0.79337411 0.16069526 0.16651883]
# Person with ID 140488670018960 generated! Interests: [0.62477757 0.37765515 0.48185898 0.48460448]
# Person with ID 140489428424880 generated! Interests: [0.07565437 0.51549725 0.63621978 0.5690021 ]
# .Person with ID 140489826517440 generated! Interests: [0.4572678  0.73504209 0.13210787 0.48287348]
# Person with ID 140489825279328 generated! Interests: [0.53611076 0.36080646 0.52901885 0.55003909]
# Person with ID 140489825279664 generated! Interests: [0.07622303 0.32586199 0.06743512 0.93992368]
# .Person with ID 140489828824304 generated! Interests: [0.53020264 0.40003349 0.55648202 0.49918547]
# Person with ID 140489828824640 generated! Interests: [0.5913444  0.53333983 0.10701411 0.5953221 ]
# Person with ID 140489797762160 generated! Interests: [0.17477241 0.75243551 0.41219466 0.48310556]
# .Person with ID 140489579414096 generated! Interests: [0.26082762 0.37863369 0.57662354 0.67535974]
# Person with ID 140489825844624 generated! Interests: [0.36176456 0.11766074 0.78887372 0.48265994]
# Person with ID 140489825842176 generated! Interests: [0.53431572 0.53832545 0.1946595  0.62194863]
# .Person with ID 140489428513744 generated! Interests: [0.17918936 0.59710751 0.74842472 0.22630561]
# Person with ID 140489826699104 generated! Interests: [0.27079333 0.55076109 0.55279324 0.56369569]
# Person with ID 140489826698720 generated! Interests: [0.5600694  0.26254202 0.30904861 0.72241464]
# .Person with ID 140489827510208 generated! Interests: [0.05014348 0.4776868  0.74261279 0.46671962]
# Person with ID 140489826661232 generated! Interests: [0.0613359  0.46201685 0.87739673 0.11381266]
# Person with ID 140489826660416 generated! Interests: [0.37403452 0.53313548 0.38684362 0.65285278]
# .Person with ID 140489430738832 generated! Interests: [0.78986753 0.46557865 0.31185566 0.24918235]
# Person with ID 140489827180896 generated! Interests: [0.3615184  0.52786809 0.76719644 0.0454901 ]
# Person with ID 140489827183536 generated! Interests: [0.59444702 0.0900876  0.50587757 0.61855061]
# .Person with ID 140489827064224 generated! Interests: [0.58453933 0.45531128 0.46999838 0.47969462]
# Person with ID 140489827062880 generated! Interests: [0.40940885 0.53342272 0.32782163 0.6636095 ]
# Person with ID 140489827063456 generated! Interests: [0.76186887 0.11549403 0.35082761 0.53210614]
# .Person with ID 140488702135360 generated! Interests: [0.44643219 0.31422555 0.18616624 0.816886  ]
# Person with ID 140489829086256 generated! Interests: [0.33382218 0.5378539  0.60984727 0.47682517]
# Person with ID 140489826584368 generated! Interests: [0.52236057 0.46814195 0.34731021 0.62238105]
# .Person with ID 140489579175504 generated! Interests: [0.0297907  0.47661307 0.03506101 0.87790843]
# Person with ID 140489831736224 generated! Interests: [0.15679535 0.6385644  0.23999187 0.71418109]
# Person with ID 140489826583120 generated! Interests: [0.55755602 0.29920131 0.32987868 0.700564  ]
# 30.Person with ID 140489640114208 generated! Interests: [0.08265553 0.34834047 0.09132887 0.92923949]
# Person with ID 140489579387296 generated! Interests: [0.27486814 0.77876837 0.25092632 0.50497852]
# Person with ID 140489829013680 generated! Interests: [0.47701425 0.5525751  0.52429399 0.43844496]
# .Person with ID 140489827395232 generated! Interests: [0.02389465 0.46840179 0.34061592 0.81486784]
# Person with ID 140489826335904 generated! Interests: [0.38954781 0.49171385 0.39807935 0.66933013]
# Person with ID 140489826336144 generated! Interests: [0.63335406 0.63015135 0.27881707 0.35218313]
# .Person with ID 140489828951184 generated! Interests: [0.07840476 0.74902936 0.30464325 0.58309536]
# Person with ID 140489826476096 generated! Interests: [0.04871751 0.19158228 0.86259453 0.46567533]
# Person with ID 140489826477536 generated! Interests: [0.66822061 0.60047009 0.32183327 0.29889836]
# .Person with ID 140489826384768 generated! Interests: [0.685238   0.22828767 0.63445583 0.27531695]
# Person with ID 140489826385056 generated! Interests: [0.58873081 0.17032782 0.76526185 0.19687246]
# Person with ID 140489755364128 generated! Interests: [0.88115311 0.22443651 0.35303099 0.22037823]
# .Person with ID 140489825925536 generated! Interests: [0.11898808 0.57078301 0.41117639 0.70070149]
# Person with ID 140489825925824 generated! Interests: [0.26363182 0.41252731 0.26940257 0.82930196]
# Person with ID 140489826384432 generated! Interests: [0.70571024 0.32034474 0.29553685 0.55857881]
# .Person with ID 140489828952096 generated! Interests: [0.75220241 0.17904463 0.25832209 0.57914096]
# Person with ID 140489825530928 generated! Interests: [0.15800871 0.71435694 0.37631521 0.56843141]
# Person with ID 140489827301072 generated! Interests: [0.37490795 0.47300153 0.26793932 0.75094747]
# .Person with ID 140489450776992 generated! Interests: [0.34664011 0.32277013 0.58441465 0.65887752]
# Person with ID 140489450776752 generated! Interests: [0.57225732 0.56756097 0.45671904 0.37656848]
# Person with ID 140489579298928 generated! Interests: [0.82691952 0.04170727 0.55047621 0.10696052]
# .Person with ID 140489827569872 generated! Interests: [0.33334822 0.92616446 0.12722417 0.12211621]
# Person with ID 140489827571072 generated! Interests: [0.28833894 0.16395384 0.73593961 0.59023104]
# Person with ID 140489428552528 generated! Interests: [0.18033703 0.47982028 0.48683893 0.7072757 ]
# .Person with ID 140489825573136 generated! Interests: [0.05296503 0.74572329 0.0033994  0.66413849]
# Person with ID 140489579301088 generated! Interests: [0.55398616 0.73490803 0.07972437 0.38295371]
# Person with ID 140489579301136 generated! Interests: [0.45845495 0.63473657 0.15290272 0.60295051]
# .Person with ID 140489827458256 generated! Interests: [0.25146178 0.88988324 0.18877736 0.33051157]
# Person with ID 140489428552288 generated! Interests: [0.14313666 0.41066239 0.78595732 0.43947626]
# Person with ID 140489829046928 generated! Interests: [0.5109501  0.44231682 0.54824216 0.49266252]
# 40.Person with ID 140489826547648 generated! Interests: [0.57501877 0.07321024 0.35968343 0.73117816]
# Person with ID 140489450765232 generated! Interests: [0.49177106 0.67123422 0.12875985 0.53946896]
# Person with ID 140489450765568 generated! Interests: [0.62860385 0.46757283 0.61987492 0.04458625]
# .Person with ID 140489825573184 generated! Interests: [0.63376216 0.17992546 0.55969737 0.50270388]
# Person with ID 140489825573280 generated! Interests: [0.54802986 0.80333946 0.10105883 0.2099907 ]
# Person with ID 140489825574576 generated! Interests: [0.58965058 0.68652228 0.21878509 0.36487318]
# .Person with ID 140489428553296 generated! Interests: [0.16970865 0.69143869 0.68869615 0.13714634]
# Person with ID 140489826298992 generated! Interests: [0.7202617  0.57670827 0.38410482 0.03307792]
# Person with ID 140489825437824 generated! Interests: [0.12641973 0.68413373 0.37966383 0.60978231]
# .Person with ID 140489829014736 generated! Interests: [0.29651085 0.48344146 0.57680995 0.58792513]
# Person with ID 140489829011520 generated! Interests: [0.12483057 0.41477885 0.88975097 0.14394113]
# Person with ID 140489829167360 generated! Interests: [0.10560051 0.86184436 0.29317104 0.40015443]
# .Person with ID 140489755247232 generated! Interests: [0.29048969 0.47001447 0.58386303 0.59481602]
# Person with ID 140489579109056 generated! Interests: [0.7529006  0.16051443 0.53369618 0.35006312]
# Person with ID 140489579108672 generated! Interests: [0.28800015 0.61496197 0.45777035 0.57386757]
# .Person with ID 140489826383040 generated! Interests: [0.15915115 0.55624766 0.4011046  0.71019332]
# Person with ID 140489829013200 generated! Interests: [0.24761566 0.37892801 0.65354915 0.60660824]
# Person with ID 140489829014544 generated! Interests: [0.71136557 0.38810037 0.56041069 0.17110521]
# .Person with ID 140489826477920 generated! Interests: [0.1611661  0.7659853  0.54946668 0.29219577]
# Person with ID 140489826333216 generated! Interests: [0.30463346 0.10169991 0.50228354 0.80284919]
# Person with ID 140489826332784 generated! Interests: [0.14209285 0.74964421 0.64639514 0.00406321]
# .Person with ID 140489826680592 generated! Interests: [0.78199949 0.18824656 0.46240548 0.37312358]
# Person with ID 140489826678480 generated! Interests: [0.65155227 0.02730657 0.53455209 0.53757609]
# Person with ID 140489827325024 generated! Interests: [0.69890257 0.54226604 0.13368926 0.44677726]
# .Person with ID 140489755310448 generated! Interests: [0.69326803 0.21204176 0.24848613 0.64239581]
# Person with ID 140489430796464 generated! Interests: [0.48643645 0.76050671 0.27479189 0.33090565]
# Person with ID 140489430738640 generated! Interests: [0.32967252 0.59837155 0.71643005 0.14140543]
# .Person with ID 140489428580768 generated! Interests: [0.61825015 0.08441928 0.7304959  0.27751734]
# Person with ID 140489428579664 generated! Interests: [0.5950634  0.02214463 0.68511331 0.41955801]
# Person with ID 140489428580960 generated! Interests: [0.78757601 0.15203348 0.09697936 0.58924091]
# 50.Person with ID 140489825276256 generated! Interests: [0.63230227 0.00432131 0.48854244 0.6012499 ]
# Person with ID 140489825278848 generated! Interests: [0.80067948 0.46971296 0.03435237 0.3702729 ]
# Person with ID 140489428387728 generated! Interests: [0.70685526 0.35900325 0.47964536 0.37604871]
# .Person with ID 140489428422768 generated! Interests: [0.8122998  0.36177236 0.12725135 0.43942791]
# Person with ID 140489826584320 generated! Interests: [0.10978963 0.17269052 0.59085175 0.78039633]
# Person with ID 140489428514704 generated! Interests: [0.59614763 0.43242491 0.67517913 0.04183113]
# .Person with ID 140489428581920 generated! Interests: [0.78531092 0.4272994  0.42527875 0.1408544 ]
# Person with ID 140489428580000 generated! Interests: [0.37960235 0.62299605 0.31836905 0.60532563]
# Person with ID 140489430748608 generated! Interests: [0.1294779  0.56495667 0.67935266 0.45004377]
# .Person with ID 140489798637936 generated! Interests: [0.4215225  0.35807501 0.16917253 0.81577063]
# Person with ID 140489828823200 generated! Interests: [0.49823708 0.37726141 0.58536759 0.51650598]
# Person with ID 140488669845968 generated! Interests: [0.62316564 0.61703495 0.42753333 0.21942586]
# .Person with ID 140489829123792 generated! Interests: [0.02886962 0.8385971  0.22795836 0.49391946]
# Person with ID 140489828210672 generated! Interests: [0.37456479 0.54311327 0.56631876 0.49397596]
# Person with ID 140489828210768 generated! Interests: [0.1413341  0.59947466 0.55980733 0.55431991]
# .Person with ID 140489829069680 generated! Interests: [0.69277873 0.5771964  0.06824864 0.42690053]
# Person with ID 140489825844672 generated! Interests: [0.50759795 0.10837545 0.78441977 0.33953603]
# Person with ID 140489825807856 generated! Interests: [0.6574532  0.09692573 0.70679303 0.24249598]
# .Person with ID 140489430714640 generated! Interests: [0.59821908 0.76101544 0.23006687 0.10029287]
# Person with ID 140489579154880 generated! Interests: [0.61742285 0.49148872 0.56495495 0.24094349]
# Person with ID 140489825533232 generated! Interests: [0.40668712 0.53544843 0.51165829 0.53488911]
# .Person with ID 140488669875936 generated! Interests: [0.53060204 0.47470714 0.68154156 0.16916177]
# Person with ID 140489825277360 generated! Interests: [0.4916902  0.22821504 0.59850498 0.58987323]
# Person with ID 140488669842064 generated! Interests: [0.41427169 0.38146107 0.61252753 0.55468589]
# .Person with ID 140488702109296 generated! Interests: [0.08623261 0.76874369 0.30104254 0.55764725]
# Person with ID 140489825530304 generated! Interests: [0.69172011 0.7196276  0.04451208 0.04096454]
# Person with ID 140489825530208 generated! Interests: [0.01780887 0.24164536 0.64698279 0.72298246]
# .Person with ID 140489428425456 generated! Interests: [0.73665991 0.1278479  0.41489117 0.5185098 ]
# Person with ID 140489827220400 generated! Interests: [0.57487969 0.44678975 0.43945915 0.52608737]
# Person with ID 140489428388208 generated! Interests: [0.3502982  0.59558795 0.32583721 0.64528775]
# 60.Person with ID 140489829071360 generated! Interests: [0.00212566 0.2409699  0.95045328 0.19638622]
# Person with ID 140489826662720 generated! Interests: [0.83206445 0.20204215 0.09310243 0.50811382]
# Person with ID 140489826663200 generated! Interests: [0.5864658  0.36742899 0.05727815 0.71956446]
# .Person with ID 140489826700544 generated! Interests: [0.62575653 0.55592297 0.44353131 0.32040348]
# Person with ID 140489797759664 generated! Interests: [0.47958895 0.12080041 0.8200371  0.28799454]
# Person with ID 140489428581728 generated! Interests: [0.5223615  0.62016006 0.48352419 0.32976404]
# .Person with ID 140489428516816 generated! Interests: [0.63243105 0.70632874 0.09680208 0.30291918]
# Person with ID 140489428513168 generated! Interests: [0.06442553 0.62902426 0.55502363 0.54048738]
# Person with ID 140489579175408 generated! Interests: [0.5700445  0.34706566 0.45257416 0.59141468]
# .Person with ID 140489428425936 generated! Interests: [0.38559366 0.81013409 0.26088871 0.35628271]
# Person with ID 140489826698576 generated! Interests: [0.59044053 0.10683985 0.68191856 0.41827301]
# Person with ID 140489430738160 generated! Interests: [0.62157898 0.64607948 0.24099278 0.37167641]
# .Person with ID 140489828950992 generated! Interests: [0.49053501 0.13591525 0.65749221 0.55552357]
# Person with ID 140489827183920 generated! Interests: [0.54267713 0.6256635  0.52923013 0.18428833]
# Person with ID 140489827181856 generated! Interests: [0.70774958 0.56706064 0.10055432 0.40917184]
# .Person with ID 140489755248768 generated! Interests: [0.21191377 0.08017645 0.62550777 0.74659515]
# Person with ID 140489828215152 generated! Interests: [0.55729637 0.18721053 0.0965155  0.80315486]
# Person with ID 140489828213760 generated! Interests: [0.57104275 0.19938358 0.43023409 0.67011565]
# .Person with ID 140489579067472 generated! Interests: [0.65721663 0.14236836 0.60205347 0.43049875]
# Person with ID 140489579068864 generated! Interests: [0.5559697  0.51974038 0.33397081 0.55608554]
# Person with ID 140489579067376 generated! Interests: [0.56544717 0.24214902 0.72550188 0.3086752 ]
# .Person with ID 140489826586048 generated! Interests: [0.61076329 0.12347006 0.74153122 0.24870625]
# Person with ID 140489825871424 generated! Interests: [0.69342254 0.56400407 0.41664618 0.16574243]
# Person with ID 140489798401856 generated! Interests: [0.2326466  0.16703438 0.90267635 0.3211705 ]
# .Person with ID 140489640014800 generated! Interests: [0.39764784 0.33609962 0.5153347  0.68069331]
# Person with ID 140489825873584 generated! Interests: [0.60407042 0.66537165 0.01005664 0.43849556]
# Person with ID 140489797846880 generated! Interests: [0.58337192 0.50721621 0.62445242 0.1116606 ]
# .Person with ID 140489450765520 generated! Interests: [0.32794096 0.62163848 0.43866349 0.55999524]
# Person with ID 140489827395616 generated! Interests: [0.49719856 0.51766521 0.64388262 0.26501226]
# Person with ID 140489827397152 generated! Interests: [0.36119674 0.09276282 0.81090006 0.45096903]
# 70.Person with ID 140489829045200 generated! Interests: [0.37045544 0.75547587 0.5280711  0.11471656]
# Person with ID 140489825926448 generated! Interests: [0.47113385 0.7826492  0.18674315 0.36141405]
# Person with ID 140489755309296 generated! Interests: [0.05184409 0.95511119 0.24536288 0.15770817]
# .Person with ID 140489579559520 generated! Interests: [0.9223196  0.02144339 0.36050207 0.13749543]
# Person with ID 140489827570688 generated! Interests: [0.36128567 0.41418822 0.8350504  0.02473083]
# Person with ID 140489827572704 generated! Interests: [0.61597341 0.20226299 0.05826994 0.75912519]
# .Person with ID 140489825571408 generated! Interests: [0.17724977 0.41630942 0.77016122 0.44957834]
# Person with ID 140489826546400 generated! Interests: [0.22819465 0.56471099 0.38235131 0.69486413]
# Person with ID 140489826549088 generated! Interests: [0.76490508 0.0377317  0.36379509 0.53023549]
# .Person with ID 140489827570160 generated! Interests: [0.32968062 0.64998059 0.10086362 0.67724623]
# Person with ID 140489826296688 generated! Interests: [0.72224978 0.62612495 0.01758505 0.29328071]
# Person with ID 140489640015472 generated! Interests: [0.45021825 0.41831651 0.74455031 0.26069072]
# .Person with ID 140489579300224 generated! Interests: [0.19965814 0.04303821 0.45106318 0.86880743]
# Person with ID 140489579302096 generated! Interests: [0.71459944 0.50986052 0.00325572 0.47893558]
# Person with ID 140489579299264 generated! Interests: [0.66118184 0.72626921 0.07707745 0.1715537 ]
# .Person with ID 140489579129008 generated! Interests: [0.36084059 0.1757991  0.74561414 0.53192885]
# Person with ID 140489579130496 generated! Interests: [0.22340113 0.21016514 0.79389026 0.5250341 ]
# Person with ID 140488669841632 generated! Interests: [0.42814358 0.29400804 0.60510903 0.60340319]
# .Person with ID 140489826518448 generated! Interests: [0.02742402 0.34330609 0.72437918 0.59721324]
# Person with ID 140489428462368 generated! Interests: [0.18616031 0.62621119 0.70249527 0.28231946]
# Person with ID 140489428461984 generated! Interests: [0.34034588 0.31759496 0.87854715 0.10701882]
# .Person with ID 140489826720736 generated! Interests: [0.47657699 0.611694   0.11758355 0.62038612]
# Person with ID 140489826718624 generated! Interests: [0.36155771 0.44078296 0.50470918 0.64827082]
# Person with ID 140489579560384 generated! Interests: [0.60760344 0.53923175 0.29563111 0.50264245]
# .Person with ID 140488670019440 generated! Interests: [0.11321955 0.65258474 0.7198848  0.20755809]
# Person with ID 140489428552864 generated! Interests: [0.2223761  0.22775939 0.9322877  0.17179693]
# Person with ID 140489640114112 generated! Interests: [0.03924486 0.5715634  0.72514865 0.38201381]
# .Person with ID 140488669875120 generated! Interests: [0.02525529 0.19125892 0.94404927 0.26749426]
# Person with ID 140489826299760 generated! Interests: [0.45813385 0.61346329 0.60816531 0.20954981]
# Person with ID 140489826297984 generated! Interests: [0.70581014 0.56995398 0.08291149 0.41244416]
# 80.Person with ID 140489755361920 generated! Interests: [0.12343638 0.68610559 0.67981259 0.22776615]
# Person with ID 140489755362064 generated! Interests: [0.75272051 0.18617335 0.1358831  0.61667422]
# Person with ID 140489755364848 generated! Interests: [0.59374829 0.54916184 0.06815689 0.58415655]
# .Person with ID 140489826585712 generated! Interests: [0.16062459 0.61780543 0.43694439 0.63371586]
# Person with ID 140489827009968 generated! Interests: [0.1017652  0.68200293 0.58354089 0.4289474 ]
# Person with ID 140489827009392 generated! Interests: [0.40654072 0.46666592 0.56362152 0.54706338]
# .Person with ID 140489579066896 generated! Interests: [0.08251499 0.41827184 0.66030796 0.61825023]
# Person with ID 140489579069344 generated! Interests: [0.18805714 0.2596933  0.67891284 0.66050833]
# Person with ID 140489640014608 generated! Interests: [0.13902057 0.65694098 0.62182571 0.40303178]
# .Person with ID 140489828952000 generated! Interests: [0.84444764 0.15721845 0.13012824 0.49523447]
# Person with ID 140489827468048 generated! Interests: [0.44893764 0.39807396 0.58780181 0.54266117]
# Person with ID 140489579106560 generated! Interests: [0.20104983 0.60407534 0.54854613 0.5420047 ]
# .Person with ID 140489828213472 generated! Interests: [0.50552066 0.70147848 0.43901213 0.24422358]
# Person with ID 140489826335856 generated! Interests: [0.56675701 0.54055659 0.39575414 0.47954533]
# Person with ID 140489826679584 generated! Interests: [0.32520962 0.77386191 0.13571484 0.52626793]
# .Person with ID 140489825923184 generated! Interests: [0.45669629 0.53728021 0.50242694 0.50032553]
# Person with ID 140489826480032 generated! Interests: [0.58207208 0.77150133 0.01722523 0.25628323]
# Person with ID 140489828952672 generated! Interests: [0.54482738 0.74226852 0.17771389 0.34730153]
# .Person with ID 140489827065184 generated! Interests: [0.47176463 0.1961339  0.75577503 0.40960192]
# Person with ID 140489430847744 generated! Interests: [0.41016008 0.23182042 0.58473081 0.66039222]
# Person with ID 140489430848128 generated! Interests: [0.53358563 0.63637732 0.55184166 0.07603337]
# .Person with ID 140489640144656 generated! Interests: [0.7313782  0.4392678  0.32803986 0.40561013]
# Person with ID 140489640142592 generated! Interests: [0.33376455 0.43866069 0.68795273 0.47212188]
# Person with ID 140489640142640 generated! Interests: [0.36370201 0.59225464 0.68090275 0.23092583]
# .Person with ID 140489430747744 generated! Interests: [0.37309813 0.44166633 0.23209376 0.78221552]
# Person with ID 140489430746160 generated! Interests: [0.61829841 0.3305978  0.70588247 0.10070807]
# Person with ID 140489430745968 generated! Interests: [0.38698864 0.2246681  0.21259997 0.86865717]
# .Person with ID 140489827424048 generated! Interests: [0.04172991 0.57356675 0.53433428 0.61948905]
# Person with ID 140489640143120 generated! Interests: [0.31808143 0.34636603 0.72543506 0.50259204]
# Person with ID 140489640143312 generated! Interests: [0.46624789 0.58364303 0.59153436 0.30341527]
# 90.Person with ID 140489428386384 generated! Interests: [0.04262631 0.91151726 0.19212312 0.36112045]
# Person with ID 140489827181664 generated! Interests: [0.80810456 0.07765371 0.51526855 0.27465479]
# Person with ID 140489827180944 generated! Interests: [0.04930969 0.63374711 0.57966355 0.50982677]
# .Person with ID 140489640141584 generated! Interests: [0.40278784 0.57813286 0.28504641 0.64982528]
# Person with ID 140489640142784 generated! Interests: [0.42088137 0.27196757 0.72158839 0.47770567]
# Person with ID 140488670002672 generated! Interests: [0.16013102 0.04989364 0.62126832 0.76543736]
# .Person with ID 140489430740464 generated! Interests: [0.52271757 0.66350979 0.48242462 0.2319215 ]
# Person with ID 140489579276032 generated! Interests: [0.06016084 0.78897081 0.29737007 0.53430027]
# Person with ID 140489579276272 generated! Interests: [0.57289131 0.70610004 0.40589508 0.09201883]
# .Person with ID 140489450697392 generated! Interests: [0.09092405 0.52379764 0.34926168 0.77161204]
# Person with ID 140489450870144 generated! Interests: [0.65137539 0.34308965 0.67099441 0.08812545]
# Person with ID 140489826549568 generated! Interests: [0.06733144 0.85086201 0.51827735 0.05374866]
# ...
# .Person with ID 140488133106128 generated! Interests: [0.16778991 0.77629025 0.48627643 0.3643559 ]
# Person with ID 140488108350960 generated! Interests: [0.18002441 0.70748123 0.55763992 0.39509397]
# Person with ID 140489826354416 generated! Interests: [0.94158042 0.25457449 0.21708554 0.03862658]
# Person with ID 140489826354896 generated! Interests: [0.11753666 0.27703472 0.78969814 0.53461551]
# Person with ID 140489826354176 generated! Interests: [0.62676042 0.63551297 0.42456999 0.15177274]
# Person with ID 140488108376128 generated! Interests: [0.23610313 0.69510042 0.67874577 0.01987201]
# Person with ID 140488132939248 generated! Interests: [0.54380642 0.6007012  0.0682193  0.58204705]
# .Person with ID 140488128615808 generated! Interests: [0.30156688 0.50320918 0.68863293 0.42617206]
# Person with ID 140489798550384 generated! Interests: [0.77549224 0.5494103  0.07411927 0.30210337]
# Person with ID 140488128613104 generated! Interests: [0.56105006 0.68583514 0.41806204 0.20019268]
# Person with ID 140488128611280 generated! Interests: [0.35421224 0.66324994 0.49037602 0.44064109]
# Person with ID 140488128611376 generated! Interests: [0.42730085 0.61255358 0.6215867  0.23626694]
# Person with ID 140488101100464 generated! Interests: [0.12772578 0.65941068 0.54491384 0.50192887]
# Person with ID 140489827455712 generated! Interests: [0.44742988 0.5788503  0.68151037 0.01680608]
# .Person with ID 140489826662528 generated! Interests: [0.65386462 0.22496824 0.38918189 0.60859495]
# Person with ID 140489826661616 generated! Interests: [0.26972122 0.31225235 0.31772128 0.85369908]
# Person with ID 140489428550416 generated! Interests: [0.16024315 0.26554385 0.37546177 0.87340544]
# Person with ID 140489428553536 generated! Interests: [0.78658227 0.003638   0.18801389 0.58815463]
# Person with ID 140489430797808 generated! Interests: [0.14160126 0.05683615 0.91254223 0.37945409]
# Person with ID 140489430796032 generated! Interests: [0.11509994 0.17675757 0.84720996 0.48759004]
# Person with ID 140488669846736 generated! Interests: [0.13041267 0.10553938 0.42069524 0.89155454]
# 80.Person with ID 140489428453888 generated! Interests: [0.40943883 0.46124015 0.51274688 0.59725037]
# Person with ID 140488702110784 generated! Interests: [0.51543483 0.11554286 0.52327624 0.66869931]
# Person with ID 140488702108144 generated! Interests: [0.43633149 0.35544087 0.82441033 0.06020159]
# Person with ID 140488429842976 generated! Interests: [0.57855129 0.64347162 0.38405878 0.32205827]
# Person with ID 140488430020016 generated! Interests: [0.82215067 0.53456615 0.1069518  0.16391651]
# Person with ID 140488430021936 generated! Interests: [0.23451769 0.68545774 0.16429723 0.66944422]
# Person with ID 140488429842832 generated! Interests: [0.60268635 0.67049953 0.31728473 0.29415973]
# .Person with ID 140488669846496 generated! Interests: [0.28368629 0.72874332 0.56860068 0.25524211]
# Person with ID 140489831736560 generated! Interests: [0.38079303 0.63744546 0.08481749 0.66442904]
# Person with ID 140489827458736 generated! Interests: [0.60939419 0.19200186 0.37015298 0.67435953]
# Person with ID 140489827457296 generated! Interests: [0.57299873 0.59940981 0.2599079  0.49480119]
# Person with ID 140488133043584 generated! Interests: [0.48700064 0.41927466 0.53540493 0.54806998]
# Person with ID 140488702264800 generated! Interests: [0.70678431 0.01854951 0.70718184 0.00238728]
# Person with ID 140488702264320 generated! Interests: [0.48072032 0.45462869 0.28168763 0.6948905 ]
# .Person with ID 140489826520608 generated! Interests: [0.44794311 0.52235454 0.14404924 0.71115576]
# Person with ID 140489828208896 generated! Interests: [0.71406835 0.00902683 0.56652721 0.41118345]
# Person with ID 140489828212112 generated! Interests: [0.7289732  0.55858167 0.24880117 0.30770533]
# Person with ID 140489826699488 generated! Interests: [0.36679246 0.00710046 0.64114816 0.67404889]
# Person with ID 140489828212688 generated! Interests: [0.62876931 0.43277279 0.41258934 0.4971186 ]
# Person with ID 140489579153200 generated! Interests: [0.00374691 0.29809121 0.74797932 0.59300466]
# Person with ID 140488429983392 generated! Interests: [0.63877466 0.42322614 0.46398567 0.44448157]
# .Person with ID 140488593991616 generated! Interests: [0.34869975 0.64866282 0.16200604 0.65680977]
# Person with ID 140488593990368 generated! Interests: [0.05801791 0.6096565  0.29284227 0.73429986]
# Person with ID 140488593989984 generated! Interests: [0.02918324 0.78118605 0.1242651  0.61110955]
# Person with ID 140488369380560 generated! Interests: [0.5096805  0.30077836 0.64965659 0.4771839 ]
# Person with ID 140488369379456 generated! Interests: [0.38719071 0.4446323  0.30529055 0.7477855 ]
# Person with ID 140488369380368 generated! Interests: [0.22835735 0.61532436 0.55858533 0.50716001]
# Person with ID 140488702223888 generated! Interests: [0.32399152 0.68887789 0.16372363 0.62743233]
# .Person with ID 140488669843024 generated! Interests: [0.71062039 0.01874805 0.55910572 0.42669424]
# Person with ID 140489579128912 generated! Interests: [0.44867582 0.0969556  0.29626852 0.83756467]
# Person with ID 140488430021600 generated! Interests: [0.69469016 0.36739867 0.06596189 0.61487628]
# Person with ID 140488369516896 generated! Interests: [0.46369015 0.26586242 0.4376729  0.72301525]
# Person with ID 140488369517520 generated! Interests: [0.70418282 0.52413545 0.39895178 0.26503974]
# Person with ID 140488369518960 generated! Interests: [0.72679834 0.24490328 0.14605506 0.62486357]
# Person with ID 140488369517088 generated! Interests: [0.03397629 0.3548376  0.70777799 0.60990673]
# .Person with ID 140489825901584 generated! Interests: [0.63719033 0.50553295 0.19464496 0.5482137 ]
# Person with ID 140489825899040 generated! Interests: [0.63805996 0.37772794 0.66635024 0.07860319]
# Person with ID 140488101831584 generated! Interests: [0.39412608 0.14453362 0.89807496 0.13128606]
# Person with ID 140488101830960 generated! Interests: [0.51001701 0.54259036 0.30782257 0.59221923]
# Person with ID 140488101831008 generated! Interests: [0.71297236 0.5903589  0.37144813 0.07192408]
# Person with ID 140488133097552 generated! Interests: [0.30865398 0.82285484 0.47709206 0.00507999]
# Person with ID 140489428364688 generated! Interests: [0.35745604 0.04641821 0.61479353 0.701498  ]
# .Person with ID 140488669859264 generated! Interests: [0.06983368 0.27028435 0.94071944 0.19265658]
# Person with ID 140488669859216 generated! Interests: [0.36104472 0.43527883 0.64618595 0.51246733]
# Person with ID 140488128641680 generated! Interests: [0.50111493 0.59438442 0.6165843  0.12415628]
# Person with ID 140488128641824 generated! Interests: [0.44270794 0.49568283 0.60188991 0.44276038]
# Person with ID 140489579276416 generated! Interests: [0.38286492 0.54568131 0.43930966 0.6022071 ]
# Person with ID 140489826382656 generated! Interests: [0.43012096 0.49881701 0.73818957 0.14578655]
# Person with ID 140489826381888 generated! Interests: [0.23124009 0.83683429 0.30178223 0.39390845]
# .Person with ID 140489579276368 generated! Interests: [0.12630262 0.08004905 0.91882107 0.36525011]
# Person with ID 140489579278096 generated! Interests: [0.56505044 0.62759714 0.42410114 0.32707499]
# Person with ID 140488133006480 generated! Interests: [0.86440451 0.02494449 0.0877836  0.49444581]
# Person with ID 140488133008736 generated! Interests: [0.81704029 0.24439051 0.08761847 0.51482175]
# Person with ID 140488133114896 generated! Interests: [0.66474523 0.62148146 0.17638757 0.37518263]
# Person with ID 140488369469280 generated! Interests: [0.65023966 0.3376572  0.65501697 0.18473973]
# Person with ID 140488369469376 generated! Interests: [0.43116024 0.46695405 0.55930897 0.53219192]
# .Person with ID 140488101833648 generated! Interests: [0.38144374 0.2162256  0.3334272  0.83460977]
# Person with ID 140489428363968 generated! Interests: [0.45398154 0.56756758 0.33743664 0.59825104]
# Person with ID 140488103753088 generated! Interests: [0.67137275 0.63225874 0.03369744 0.38519086]
# Person with ID 140488101698816 generated! Interests: [0.36351472 0.05535436 0.86713755 0.33595447]
# Person with ID 140488101698672 generated! Interests: [0.83070036 0.428062   0.0420123  0.35346118]
# Person with ID 140488101698288 generated! Interests: [0.55741839 0.43423808 0.65747838 0.26161843]
# Person with ID 140488369448512 generated! Interests: [0.25628004 0.67654762 0.11409032 0.68087243]
# .Person with ID 140488103752320 generated! Interests: [0.17643923 0.28686718 0.67003199 0.66153878]
# Person with ID 140489826383904 generated! Interests: [0.03529542 0.66979361 0.64177674 0.37182438]
# Person with ID 140488133042336 generated! Interests: [0.79828886 0.06075977 0.29147977 0.52352907]
# Person with ID 140488101265120 generated! Interests: [0.08387916 0.93260745 0.3509814  0.00443678]
# Person with ID 140488101262576 generated! Interests: [0.63236631 0.7399495  0.21973528 0.06560482]
# Person with ID 140488101263296 generated! Interests: [0.1778322  0.59959072 0.6005617  0.49818904]
# Person with ID 140489579277904 generated! Interests: [0.26457307 0.68197292 0.57907981 0.35997306]
# 90.Person with ID 140488103750528 generated! Interests: [0.71029655 0.19938531 0.29056149 0.60934254]
# Person with ID 140488103787824 generated! Interests: [0.6996434  0.15743235 0.66568692 0.20633734]
# Person with ID 140488103787152 generated! Interests: [0.01080818 0.21029498 0.68428592 0.69814897]
# Person with ID 140488103785328 generated! Interests: [0.6737513  0.55491677 0.39495609 0.28659422]
# Person with ID 140488103785376 generated! Interests: [0.50496219 0.55468369 0.63693521 0.17791213]
# Person with ID 140488103514224 generated! Interests: [0.17074232 0.00175433 0.96761202 0.18593268]
# Person with ID 140488103517104 generated! Interests: [0.64768562 0.01079516 0.11897605 0.75248356]
# .Person with ID 140488101852832 generated! Interests: [0.24830393 0.51575327 0.64159219 0.51059101]
# Person with ID 140488101853072 generated! Interests: [0.52630347 0.37295293 0.18386757 0.74168961]
# Person with ID 140488702166448 generated! Interests: [0.22072063 0.66041598 0.03199304 0.71701435]
# Person with ID 140488702168656 generated! Interests: [0.21606123 0.39832433 0.67916812 0.57739582]
# Person with ID 140488702168896 generated! Interests: [0.47878561 0.63650126 0.47126563 0.37886566]
# Person with ID 140488133115328 generated! Interests: [0.71328274 0.17484035 0.27662684 0.6197872 ]
# Person with ID 140488133114320 generated! Interests: [0.11422028 0.61512061 0.52553599 0.57653473]
# .Person with ID 140489825926928 generated! Interests: [0.39098398 0.15269499 0.59891724 0.6819926 ]
# Person with ID 140489825925104 generated! Interests: [0.26261091 0.24291928 0.77516884 0.52071011]
# Person with ID 140488133007584 generated! Interests: [0.67471806 0.34662168 0.27822627 0.58923603]
# Person with ID 140488133009264 generated! Interests: [0.33185132 0.75475879 0.2166907  0.52274182]
# Person with ID 140489825900480 generated! Interests: [0.07761727 0.40032463 0.05900818 0.91117166]
# Person with ID 140489825901536 generated! Interests: [0.46596892 0.4003199  0.78726829 0.05315619]
# Person with ID 140488133006240 generated! Interests: [0.32641592 0.70783402 0.62615249 0.0188868 ]
# .Person with ID 140488369516608 generated! Interests: [0.07141749 0.72576975 0.08751598 0.67860059]
# Person with ID 140488369520160 generated! Interests: [0.20588047 0.82439833 0.46539048 0.24777473]
# Person with ID 140489828209280 generated! Interests: [0.49267408 0.6737345  0.25697965 0.48715043]
# Person with ID 140489828209376 generated! Interests: [0.6172389  0.48264091 0.60380647 0.14660029]
# Person with ID 140488369519296 generated! Interests: [0.47516113 0.5799507  0.57693106 0.32408275]
# Person with ID 140489827467760 generated! Interests: [0.398726   0.64886031 0.14928576 0.63064382]
# Person with ID 140489827469968 generated! Interests: [0.11054826 0.52780631 0.83167373 0.13235708]
# .Person with ID 140488103470896 generated! Interests: [0.49726382 0.21092905 0.6309936  0.5568525 ]
# Person with ID 140489755308192 generated! Interests: [0.10001921 0.96193129 0.04682438 0.24998367]
# Person with ID 140489826519840 generated! Interests: [0.4417235  0.45687983 0.66297135 0.39574002]
# Person with ID 140489826519648 generated! Interests: [0.1651812  0.09851744 0.93306279 0.30397915]
# Person with ID 140488369319072 generated! Interests: [0.19011179 0.39567076 0.45868444 0.77259999]
# Person with ID 140488369318592 generated! Interests: [0.7338737  0.28318835 0.28468395 0.54789488]
# Person with ID 140489831738096 generated! Interests: [0.52375945 0.46716239 0.39813295 0.59069916]
# .Person with ID 140489428363584 generated! Interests: [0.26488629 0.84431278 0.45610378 0.09455437]
# Person with ID 140489826661088 generated! Interests: [0.51862597 0.54825755 0.27249399 0.59681471]
# Person with ID 140489826663056 generated! Interests: [0.61614941 0.23739817 0.71941027 0.21552464]
# Person with ID 140489428581584 generated! Interests: [0.46675529 0.72823739 0.19124471 0.46393454]
# Person with ID 140488429843744 generated! Interests: [0.14543583 0.36360406 0.89531934 0.21223522]
# Person with ID 140488429842784 generated! Interests: [0.52269536 0.70592534 0.22800265 0.42008781]
# Person with ID 140489428451968 generated! Interests: [0.47088877 0.60167403 0.63618383 0.10734182]
# .Person with ID 140489640031616 generated! Interests: [0.41362338 0.83552813 0.36147931 0.0118809 ]
# Person with ID 140488108409136 generated! Interests: [0.10222622 0.50963797 0.21930466 0.82566604]
# Person with ID 140488429951200 generated! Interests: [0.69869472 0.69709873 0.08015465 0.13947857]
# Person with ID 140488101851632 generated! Interests: [0.38111592 0.09074033 0.70005827 0.597022  ]
# Person with ID 140489640033008 generated! Interests: [0.70462695 0.03684277 0.64000615 0.30419664]
# Person with ID 140489826519504 generated! Interests: [0.84512812 0.30931862 0.43183126 0.06001846]
# Person with ID 140489826519984 generated! Interests: [0.41859987 0.0166353  0.61615616 0.66697001]
# .Person with ID 140488369495200 generated! Interests: [0.49575618 0.76618804 0.11080036 0.39357971]
# Person with ID 140488369495440 generated! Interests: [0.45381377 0.83841042 0.21723864 0.20959104]
# Person with ID 140488669844144 generated! Interests: [0.53877304 0.08530946 0.64708859 0.53265586]
# Person with ID 140488669844768 generated! Interests: [0.72947145 0.37299851 0.32120399 0.47494369]
# Person with ID 140488669844528 generated! Interests: [0.43736981 0.48848385 0.46019744 0.59858959]
# Person with ID 140488669847504 generated! Interests: [0.64524234 0.40919105 0.60384343 0.22715222]
# Person with ID 140489827397440 generated! Interests: [0.57578058 0.15620933 0.55299071 0.58161554]
# .Person with ID 140488128456880 generated! Interests: [0.69483617 0.16453042 0.57080384 0.40535838]
# Person with ID 140489827011792 generated! Interests: [0.0759172  0.11592611 0.63815166 0.75733756]
# Person with ID 140488702109680 generated! Interests: [0.60246915 0.37074817 0.40791353 0.57722029]
# Person with ID 140488702110688 generated! Interests: [0.39553064 0.63498272 0.54605794 0.37705859]
# Person with ID 140489827219344 generated! Interests: [0.04120362 0.2184225  0.93597726 0.27302097]
# Person with ID 140488670008512 generated! Interests: [0.20596795 0.56103167 0.5389919  0.59355573]
# Person with ID 140488670009520 generated! Interests: [0.35283591 0.68253984 0.51021686 0.38642586]
# .Person with ID 140488101323344 generated! Interests: [0.05974527 0.63215272 0.04890364 0.7709876 ]
# Person with ID 140488101324160 generated! Interests: [0.52837795 0.61571014 0.3233114  0.487019  ]
# Person with ID 140488369395840 generated! Interests: [0.81097763 0.36951126 0.32176949 0.31975164]
# Person with ID 140488369395552 generated! Interests: [0.58018341 0.16193183 0.78949166 0.11776339]
# Person with ID 140488369394016 generated! Interests: [0.00770308 0.70390542 0.0617889  0.70755915]
# Person with ID 140489825871280 generated! Interests: [0.09450277 0.82061536 0.53682622 0.17168942]
# Person with ID 140488369396416 generated! Interests: [0.58273153 0.70134008 0.20941548 0.35311644]

# %% [markdown]
# Notes to self:
#
# - Make sure the start where we send people in works rigth, what if the start line is not empty --> TODO: Handle this
# - Print Round number
# - Timestep in this round
# - Print Frequency of sending people in this set
# - Number of people present
# - Fraction of space occupied
# - Number of people exited
#
#
#
# ## At each point, we want to let n number of people enter (TODO: EDIT)
# ### Ex: 7 people per round
#
# ## People's trajectory/calculation of priority scores will be a function of:
# * Their interests alignment with exhibit topic(s)
# * Whether they've seen an exhinit or not (don't consider it again once visited) (will go towards the exhibit with highest priority score)
# * How long they've stayed in the simulation (Don't want to stay too long)
# *
#
# ## (+ rules and other specified constraints)
# * Visiting/seeing/checking out an exhibit consists of being within 1 unit from their "center" ```ex[n]c```.
# * Person seeing an exhibit for 1 iteration marks it as visited.

# %%
# plt.scatter([(1,2), (3,4)], alpha=0.5)
# plt.show()
((2 < 2) * -1) + ((2 > 2) * 1 )
# Out:
# 0

# %%
# ?random.randint
# ?np.linalg.norm

# np.random.rand(4)

# %%
# import numpy as np
#?np.linalg.norm
#https://www.geeksforgeeks.org/how-to-get-weighted-random-choice-in-python/
import random
  

sampleList = [100, 200, 300, 400, 500]

randomList = random.choices(sampleList, weights=(10, 20, 30, 40, 50), k=1)[0]

print(randomList)
# Out:
# 400

# %% [markdown]
# Further rules and possibilites to make a more intricate model:
# * If seeing an exhibit, How long they've already been here (as opposed to fixed 1 iteration being considered visited)
# * One person can only occupy a single block, and a single block can at most be occupied by one person

# %%
# from matplotlib.animation import FFMpegWriter
# metadata = dict(title='My first animation in 2D', artist='Matplotlib',comment='Wakanda is coming.')
# writer = FFMpegWriter(fps=15, metadata=metadata)
# fig = plt.figure()

# with writer.saving(fig, "wave1d.mp4", dpi=200):
#     nf = 100
#     for it in range(nf):
#         if (it%10==0): print(it,end='')
#         print('.',end='')

#         n = 50
#         y = np.zeros(n)
#         f = 2.0*np.pi/n
#         for i in range(n):
#             y[i] = np.cos(f*(i+it)) + np.sin(f*it)*np.cos(3*f*(i+it))
#         plt.clf()
#         plt.plot(y, 'ro-',mfc='w')
#         plt.show()
#         plt.draw()
#         plt.pause(0.05)
#         writer.grab_frame()

# %%
# # @@ Cell 11 (RECOVERED):
# #testing
# board2 = np.zeros(board_org.shape)
# board2[5,5] = 10
# plt.clf()
# plt.imshow(board_org)
# plt.imshow(board2, alpha=0.5, cmap="binary")
# plt.show()
